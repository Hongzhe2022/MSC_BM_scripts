# %%
# Doublets exclusion analysis

# %%
import scvelo as scv
import loompy
import scanpy
#import scanpy.api
import igraph
import phate
import glob, os
import pandas as pd
import os
import re
import subprocess
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from copy import copy

# %%
ifile = "/projects/fs1/common/Hongzhe/Hongze_healthy_2020_10_downsampled_1000_2D_overclustered_doubletsRemoved.h5ad"
adata = scv.read(ifile)

# %%
#create MSC subset

# %%
louvain11_merged95_renamedGOI = ['3','5', '16','29','23','38','6','8', '37']
adata_MSC = adata[adata.obs['louvain11_merged.95_renamed'].isin(louvain11_merged95_renamedGOI)]
lin=('3','5','16','38','29','23','6','37','8')
adata_MSC.obs['louvain11_merged.95_renamed']=adata_MSC.obs['louvain11_merged.95_renamed'].cat.reorder_categories(list(lin),ordered=True)
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
var_names=['SRGN','CD52','CD37','CD48','PTPRC']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,5),save='hema_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_hema_marker_DR.pdf

# %%
var_names=['S100A4','S100A6','S100A8','S100A9','S100A10','S100A12']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,6),save='fibro_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_fibro_marker_DR.pdf

# %%
var_names=['CEBPD','LPL','PLIN1','ADIPOQ','CCL2','PPARG']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,6),save='adipo_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_adipo_marker_DR.pdf

# %%
var_names=['BGLAP','CHAD','SPP1','RUNX2','PRRX1','CDH11','CDH2','FAP','SPARC']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,9),save='OC_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_OC_marker_DR.pdf

# %%
var_names=['FOS','FOSB','JUNB','EGR1']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,4),save='stress_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_stress_marker_DR.pdf

# %%
var_names=['NNMT','IFITM3','DCN','CXCL12','CFD','PTGDS','APOE','LEPR','TF','CHL1','VCAN','IGFBP5']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,12),save='stromal_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_stromal_marker_DR.pdf

# %%
var_names=['GAS6','FBN1','SPARCL1','ALPL','RUNX1','CDH11','SNAI2','EBF1','EBF3']
scanpy.pl.stacked_violin(adata_MSC,var_names, groupby='louvain11_merged.95_renamed',
                  swap_axes=True,cmap='coolwarm',figsize=(9,9),save='osteo_marker_DR')
# Out:
# WARNING: saving figure to file figures/stacked_violin_osteo_marker_DR.pdf
